# %% [markdown]
# # YOLOv9 Experiments

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/New-Human-Face-Detections.7z'

# %%
# !cp {zip_dataset_path} /content/

# %%
!7z x /content/New-Human-Face-Detections.7z -o/content/dataset/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 346622433 bytes (331 MiB)
#
# Extracting archive: /content/New-Human-Face-Detections.7z
# --
# Path = /content/New-Human-Face-Detections.7z
# Type = 7z
# Physical Size = 346622433
# Headers Size = 397221
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 10
# Files: 17769
# Size:       352299353
# Compressed: 346622433

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.226-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.226-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.226 ultralytics-thop-2.0.18

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)  # type: ignore
# Out:
# CUDA available: True
# Device name: NVIDIA A100-SXM4-40GB
# CUDA version: 12.6

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Dataset YAML Path
data_path = "/content/dataset/New-Human-Face-Detections/data.yaml"

# Project Name
project_name = "emotion_detection_yolov9_comparison"

# %%
# Training Parameter
train_params = {
    "epochs": 120,
    "patience": 20,
    "batch": 32,
    "imgsz": 640,
    "save": True,
    "save_period": 20,
    "device": 0,
    "pretrained":True,
    "optimizer": "AdamW",
    "seed": 3407,
    "cos_lr": True,
    "close_mosaic": True,
    "freeze": 5,
    "lr0": 0.001,
    "lrf": 0.01,
    "momentum": 0.9,
    "val": True,
    "plots": True,

    # Augmentations
    "hsv_h": 0.015, # Variasi Random Color
    "hsv_s": 0.7,   # Saturation Randomness
    "hsv_v": 0.4,   # Brightness Randomness
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
}

# %%
# Validation Parameter
val_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'val',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %%
# Testing Parameter
test_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'test',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %% [markdown]
# ## YOLOv9t (Tiny Size)

# %% [markdown]
# ### Train

# %%
model_t = YOLO("yolov9t.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.0MB/s]

# %%
t_result = model_t.train(
    data=data_path,
    project=project_name,
    name="yolov9t_train_results",
    **train_params
)

# %% [markdown]
# ### Validation

# %%
model_t_val = YOLO("path/to/best.pt")

# %%
val_n_result = model_t_val.val(
    data=data_path,
    project=project_name,
    name="yolov9t_validation_results",
    **val_params
)

# %% [markdown]
# ### Testing

# %%
model_t_test = YOLO("path/to/best.pt")

# %%
test_t_result = model_t_test.val(
    data=data_path,
    project=project_name,
    name="yolov9t_testing_results",
    **test_params
)

# %% [markdown]
# ## YOLOv9s (Small Size)

# %% [markdown]
# ### Train

# %%
model_s = YOLO("yolov9s.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.0MB/s]

# %%
s_result = model_s.train(
    data=data_path,
    project=project_name,
    name="yolov9s_train_results",
    **train_params
)

# %% [markdown]
# ### Validation

# %%
model_s_val = YOLO("path/to/best.pt")

# %%
val_s_result = model_s_val.val(
    data=data_path,
    project=project_name,
    name="yolov9s_validation_results",
    **val_params
)

# %% [markdown]
# ### Testing

# %%
model_s_test = YOLO("path/to/best.pt")

# %%
test_s_result = model_s_test.val(
    data=data_path,
    project=project_name,
    name="yolov9s_testing_results",
    **test_params
)

# %% [markdown]
# ## YOLOv9m (Medium Size)

# %% [markdown]
# ### Train

# %%
model_m = YOLO("yolov9m.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov9m.pt to 'yolov9m.pt': 100% ━━━━━━━━━━━━ 39.1MB 193.8MB/s 0.2s

# %%
m_result = model_m.train(
    data=data_path,
    project=project_name,
    name="yolov9m_train_results",
    **train_params
)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=True, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/dataset/New-Human-Face-Detections/data.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=120, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=5, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov9m.pt, momentum=0.9, mosaic=1.0, multi_scale=False, name=yolov9m_train_results, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=emotion_detection_yolov9_comparison, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/emotion_detection_yolov9_comparison/yolov9m_train_results, save_frames=False, save_json=False, save_period=20, save_txt=False, scale=0.5, seed=3407, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1    171648  ultralytics.nn.modules.block.RepNCSPELAN4    [64, 128, 128, 64, 1]
#   3                  -1  1    276960  ultralytics.nn.modules.block.AConv           [128, 240]
#   4                  -1  1    629520  ultralytics.nn.modules.block.RepNCSPELAN4    [240, 240, 240, 120, 1]
#   5                  -1  1    778320  ultralytics.nn.modules.block.AConv           [240, 360]
#   6                  -1  1   1414080  ultralytics.nn.modules.block.RepNCSPELAN4    [360, 360, 360, 180, 1]
#   7                  -1  1   1556160  ultralytics.nn.modules.block.AConv           [360, 480]
#   8                  -1  1   2511840  ultralytics.nn.modules.block.RepNCSPELAN4    [480, 480, 480, 240, 1]
#   9                  -1  1    577440  ultralytics.nn.modules.block.SPPELAN         [480, 480, 240]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1   1586880  ultralytics.nn.modules.block.RepNCSPELAN4    [840, 360, 360, 180, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    715920  ultralytics.nn.modules.block.RepNCSPELAN4    [600, 240, 240, 120, 1]
#  16                  -1  1    397808  ultralytics.nn.modules.block.AConv           [240, 184]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1   1480320  ultralytics.nn.modules.block.RepNCSPELAN4    [544, 360, 360, 180, 1]
#  19                  -1  1    778080  ultralytics.nn.modules.block.AConv           [360, 240]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   2627040  ultralytics.nn.modules.block.RepNCSPELAN4    [720, 480, 480, 240, 1]
#  22        [15, 18, 21]  1   4642600  ultralytics.nn.modules.head.Detect           [8, [240, 360, 480]]
# YOLOv9m summary: 348 layers, 20,164,104 parameters, 20,164,088 gradients, 77.6 GFLOPs
#
# Transferred 901/907 items from pretrained weights
# Freezing layer 'model.0.conv.weight'
# Freezing layer 'model.0.bn.weight'
# Freezing layer 'model.0.bn.bias'
# Freezing layer 'model.1.conv.weight'
# Freezing layer 'model.1.bn.weight'
# Freezing layer 'model.1.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.0.cv1.conv.weight'
# Freezing layer 'model.2.cv2.0.cv1.bn.weight'
# Freezing layer 'model.2.cv2.0.cv1.bn.bias'
# Freezing layer 'model.2.cv2.0.cv2.conv.weight'
# Freezing layer 'model.2.cv2.0.cv2.bn.weight'
# Freezing layer 'model.2.cv2.0.cv2.bn.bias'
# Freezing layer 'model.2.cv2.0.cv3.conv.weight'
# Freezing layer 'model.2.cv2.0.cv3.bn.weight'
# Freezing layer 'model.2.cv2.0.cv3.bn.bias'
# Freezing layer 'model.2.cv2.0.m.0.cv1.conv1.conv.weight'
# Freezing layer 'model.2.cv2.0.m.0.cv1.conv1.bn.weight'
# Freezing layer 'model.2.cv2.0.m.0.cv1.conv1.bn.bias'
# Freezing layer 'model.2.cv2.0.m.0.cv1.conv2.conv.weight'
# Freezing layer 'model.2.cv2.0.m.0.cv1.conv2.bn.weight'
# Freezing layer 'model.2.cv2.0.m.0.cv1.conv2.bn.bias'
# Freezing layer 'model.2.cv2.0.m.0.cv2.conv.weight'
# Freezing layer 'model.2.cv2.0.m.0.cv2.bn.weight'
# Freezing layer 'model.2.cv2.0.m.0.cv2.bn.bias'
# Freezing layer 'model.2.cv2.1.conv.weight'
# Freezing layer 'model.2.cv2.1.bn.weight'
# Freezing layer 'model.2.cv2.1.bn.bias'
# Freezing layer 'model.2.cv3.0.cv1.conv.weight'
# Freezing layer 'model.2.cv3.0.cv1.bn.weight'
# Freezing layer 'model.2.cv3.0.cv1.bn.bias'
# Freezing layer 'model.2.cv3.0.cv2.conv.weight'
# Freezing layer 'model.2.cv3.0.cv2.bn.weight'
# Freezing layer 'model.2.cv3.0.cv2.bn.bias'
# Freezing layer 'model.2.cv3.0.cv3.conv.weight'
# Freezing layer 'model.2.cv3.0.cv3.bn.weight'
# Freezing layer 'model.2.cv3.0.cv3.bn.bias'
# Freezing layer 'model.2.cv3.0.m.0.cv1.conv1.conv.weight'
# Freezing layer 'model.2.cv3.0.m.0.cv1.conv1.bn.weight'
# Freezing layer 'model.2.cv3.0.m.0.cv1.conv1.bn.bias'
# Freezing layer 'model.2.cv3.0.m.0.cv1.conv2.conv.weight'
# Freezing layer 'model.2.cv3.0.m.0.cv1.conv2.bn.weight'
# Freezing layer 'model.2.cv3.0.m.0.cv1.conv2.bn.bias'
# Freezing layer 'model.2.cv3.0.m.0.cv2.conv.weight'
# Freezing layer 'model.2.cv3.0.m.0.cv2.bn.weight'
# Freezing layer 'model.2.cv3.0.m.0.cv2.bn.bias'
# Freezing layer 'model.2.cv3.1.conv.weight'
# Freezing layer 'model.2.cv3.1.bn.weight'
# Freezing layer 'model.2.cv3.1.bn.bias'
# Freezing layer 'model.2.cv4.conv.weight'
# Freezing layer 'model.2.cv4.bn.weight'
# Freezing layer 'model.2.cv4.bn.bias'
# Freezing layer 'model.3.cv1.conv.weight'
# Freezing layer 'model.3.cv1.bn.weight'
# Freezing layer 'model.3.cv1.bn.bias'
# Freezing layer 'model.4.cv1.conv.weight'
# Freezing layer 'model.4.cv1.bn.weight'
# Freezing layer 'model.4.cv1.bn.bias'
# Freezing layer 'model.4.cv2.0.cv1.conv.weight'
# Freezing layer 'model.4.cv2.0.cv1.bn.weight'
# Freezing layer 'model.4.cv2.0.cv1.bn.bias'
# Freezing layer 'model.4.cv2.0.cv2.conv.weight'
# Freezing layer 'model.4.cv2.0.cv2.bn.weight'
# Freezing layer 'model.4.cv2.0.cv2.bn.bias'
# Freezing layer 'model.4.cv2.0.cv3.conv.weight'
# Freezing layer 'model.4.cv2.0.cv3.bn.weight'
# Freezing layer 'model.4.cv2.0.cv3.bn.bias'
# Freezing layer 'model.4.cv2.0.m.0.cv1.conv1.conv.weight'
# Freezing layer 'model.4.cv2.0.m.0.cv1.conv1.bn.weight'
# Freezing layer 'model.4.cv2.0.m.0.cv1.conv1.bn.bias'
# Freezing layer 'model.4.cv2.0.m.0.cv1.conv2.conv.weight'
# Freezing layer 'model.4.cv2.0.m.0.cv1.conv2.bn.weight'
# Freezing layer 'model.4.cv2.0.m.0.cv1.conv2.bn.bias'
# Freezing layer 'model.4.cv2.0.m.0.cv2.conv.weight'
# Freezing layer 'model.4.cv2.0.m.0.cv2.bn.weight'
# Freezing layer 'model.4.cv2.0.m.0.cv2.bn.bias'
# Freezing layer 'model.4.cv2.1.conv.weight'
# Freezing layer 'model.4.cv2.1.bn.weight'
# Freezing layer 'model.4.cv2.1.bn.bias'
# Freezing layer 'model.4.cv3.0.cv1.conv.weight'
# Freezing layer 'model.4.cv3.0.cv1.bn.weight'
# Freezing layer 'model.4.cv3.0.cv1.bn.bias'
# Freezing layer 'model.4.cv3.0.cv2.conv.weight'
# Freezing layer 'model.4.cv3.0.cv2.bn.weight'
# Freezing layer 'model.4.cv3.0.cv2.bn.bias'
# Freezing layer 'model.4.cv3.0.cv3.conv.weight'
# Freezing layer 'model.4.cv3.0.cv3.bn.weight'
# Freezing layer 'model.4.cv3.0.cv3.bn.bias'
# Freezing layer 'model.4.cv3.0.m.0.cv1.conv1.conv.weight'
# Freezing layer 'model.4.cv3.0.m.0.cv1.conv1.bn.weight'
# Freezing layer 'model.4.cv3.0.m.0.cv1.conv1.bn.bias'
# Freezing layer 'model.4.cv3.0.m.0.cv1.conv2.conv.weight'
# Freezing layer 'model.4.cv3.0.m.0.cv1.conv2.bn.weight'
# Freezing layer 'model.4.cv3.0.m.0.cv1.conv2.bn.bias'
# Freezing layer 'model.4.cv3.0.m.0.cv2.conv.weight'
# Freezing layer 'model.4.cv3.0.m.0.cv2.bn.weight'
# Freezing layer 'model.4.cv3.0.m.0.cv2.bn.bias'
# Freezing layer 'model.4.cv3.1.conv.weight'
# Freezing layer 'model.4.cv3.1.bn.weight'
# Freezing layer 'model.4.cv3.1.bn.bias'
# Freezing layer 'model.4.cv4.conv.weight'
# Freezing layer 'model.4.cv4.bn.weight'
# Freezing layer 'model.4.cv4.bn.bias'
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 71.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1279.0±365.0 MB/s, size: 37.1 KB)
# train: Scanning /content/dataset/New-Human-Face-Detections/train/labels... 6221 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6221/6221 1.6Kit/s 4.0s
# train: New cache created: /content/dataset/New-Human-Face-Detections/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1161.5±651.3 MB/s, size: 34.9 KB)
# val: Scanning /content/dataset/New-Human-Face-Detections/valid/labels... 1772 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1772/1772 1.2Kit/s 1.5s
# val: New cache created: /content/dataset/New-Human-Face-Detections/valid/labels.cache
# Plotting labels to /content/emotion_detection_yolov9_comparison/yolov9m_train_results/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 149 weight(decay=0.0), 156 weight(decay=0.0005), 155 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/emotion_detection_yolov9_comparison/yolov9m_train_results
# Starting training for 120 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/120      7.34G     0.8927      1.958       1.43         36        640: 100% ━━━━━━━━━━━━ 195/195 4.3it/s 45.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.0it/s 9.4s
#                    all       1772       1785      0.318      0.585      0.361      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/120      9.38G     0.8299       1.65       1.37         30        640: 100% ━━━━━━━━━━━━ 195/195 4.7it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785       0.35      0.666      0.422      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/120      9.46G     0.7766      1.559       1.32         35        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.352      0.523       0.44      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/120      9.54G       0.75       1.51      1.303         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785       0.33      0.664      0.466       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/120      9.62G     0.7346      1.473      1.286         38        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.412      0.685      0.515      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/120      9.71G     0.6863      1.425      1.249         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.419      0.707      0.544      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/120      9.79G     0.6679      1.396      1.236         40        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.476      0.681      0.579       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/120      9.87G     0.6636      1.373      1.229         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.452      0.668      0.533      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/120      9.95G     0.6498      1.349      1.221         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.3it/s 8.4s
#                    all       1772       1785      0.461      0.687      0.566      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/120        10G     0.6439      1.341      1.217         34        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.469      0.663      0.593      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/120      10.1G     0.6572      1.322      1.223         38        640: 100% ━━━━━━━━━━━━ 195/195 4.8it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.481      0.672      0.598      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/120      10.2G     0.6346      1.315      1.208         41        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.487      0.718      0.625      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/120      10.3G     0.6198      1.293      1.197         41        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.504       0.64      0.608       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/120      10.4G     0.6243      1.282      1.202         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.439      0.704      0.592      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/120      10.4G     0.6091       1.27      1.192         34        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.547      0.644      0.652      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/120      10.5G     0.6045       1.26      1.188         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.613      0.653      0.682      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/120      10.6G     0.5976      1.244      1.186         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.561      0.657      0.664      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/120      10.7G     0.6011      1.241      1.185         33        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.563      0.695      0.659      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/120      10.8G       0.59      1.229      1.178         39        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.521      0.686      0.666      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/120      10.8G     0.5957      1.203       1.18         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.591      0.635      0.677      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/120      10.9G     0.5831      1.195      1.171         31        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.623      0.675      0.692      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/120        11G      0.587      1.188      1.176         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785       0.58      0.719      0.701      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/120      11.1G     0.5726      1.162      1.165         27        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.602      0.697      0.709      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/120      11.2G     0.5777      1.176      1.167         34        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.623      0.699      0.718      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/120      11.3G     0.5738       1.15      1.166         34        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.605      0.679      0.707       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/120      11.3G     0.5687      1.145      1.161         28        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.604      0.724       0.72      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/120      11.4G     0.5698      1.137      1.159         32        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.636      0.699      0.722      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/120      11.5G     0.5651      1.116      1.154         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.589      0.726      0.709      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/120      11.6G      0.559      1.112      1.156         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.614      0.713      0.721      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/120      11.7G      0.556      1.108      1.151         34        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.668      0.689      0.731      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/120      11.7G     0.5565      1.101      1.152         38        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.612      0.721      0.718      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/120      11.8G     0.5479      1.081      1.143         33        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.624      0.685      0.703      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/120      11.9G      0.549      1.084      1.143         31        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.603      0.681        0.7      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/120        12G      0.548      1.072      1.147         31        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.639      0.686      0.725      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/120      12.1G     0.5473      1.063      1.148         41        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.669      0.663      0.717      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/120      12.2G      0.537      1.048      1.136         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.693      0.675      0.733      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/120      12.2G     0.5325      1.041      1.137         34        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.625      0.722      0.738      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/120      12.3G     0.5366      1.044      1.137         40        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.665      0.677      0.731      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/120      12.4G     0.5295      1.026      1.134         38        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.628       0.72      0.721      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/120      12.5G     0.5323      1.026      1.132         35        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.609      0.727      0.729      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/120      12.6G     0.5324      1.007      1.134         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.633      0.704      0.725      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/120      12.6G     0.5297       1.01      1.131         42        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.658      0.677      0.731      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/120      12.7G     0.5225     0.9875       1.13         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.604      0.721      0.708      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/120      12.8G      0.528     0.9893      1.131         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.633      0.727      0.728      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/120      12.9G     0.5262     0.9886      1.132         31        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.653      0.695      0.733       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/120        13G     0.5211     0.9753      1.123         32        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.664      0.696      0.739       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/120      13.1G     0.5033     0.9541      1.114         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.644      0.699      0.728      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/120      13.1G     0.5104     0.9522      1.123         33        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.622      0.726      0.732      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/120      13.2G     0.5131     0.9503      1.118         35        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.659      0.657       0.72       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/120      13.3G     0.5126     0.9582      1.122         39        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.664      0.686      0.736      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/120      13.4G     0.5108     0.9343      1.119         33        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.656      0.688       0.73      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/120      13.5G     0.5101     0.9384      1.119         32        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785       0.61      0.726      0.726      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/120      13.5G     0.5032     0.9236      1.113         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.652        0.7      0.726      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/120      13.6G     0.5034     0.9153      1.113         40        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.653      0.716      0.735      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/120      13.7G     0.4913     0.9047      1.105         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.1s
#                    all       1772       1785      0.681      0.683      0.737      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/120      13.8G     0.4982     0.9047      1.106         46        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.1s
#                    all       1772       1785      0.643      0.716       0.73      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/120      13.9G     0.4979     0.8974      1.109         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.1s
#                    all       1772       1785      0.657      0.718      0.734      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/120      13.9G     0.4911     0.8971      1.107         40        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.1s
#                    all       1772       1785      0.628      0.729      0.723      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/120        14G      0.497     0.8929       1.11         41        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.704      0.682      0.745      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/120      14.1G     0.4826     0.8609      1.101         40        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.627      0.726      0.721      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/120      14.2G     0.4908      0.879      1.109         33        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all       1772       1785      0.663      0.702      0.734      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/120      14.3G     0.4809     0.8708      1.099         39        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.683       0.67      0.735      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/120      14.4G     0.4857     0.8593      1.104         34        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.658       0.71      0.734      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/120      14.4G      0.482     0.8542      1.101         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.1s
#                    all       1772       1785       0.65      0.715      0.735      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/120      14.5G     0.4746     0.8434      1.095         43        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.657       0.71      0.729      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/120      14.6G     0.4731     0.8433      1.094         32        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.662      0.695      0.732      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/120      14.7G     0.4734     0.8359      1.093         30        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.1s
#                    all       1772       1785      0.681      0.696       0.73      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/120      14.8G     0.4732      0.824      1.094         32        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.1s
#                    all       1772       1785      0.671      0.699       0.73      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/120        15G     0.4701     0.8188      1.091         38        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.1s
#                    all       1772       1785      0.673      0.692      0.729      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/120      15.1G     0.4679     0.8093      1.093         27        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.1s
#                    all       1772       1785      0.665      0.686      0.719      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/120      15.1G     0.4644     0.8069      1.089         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.1s
#                    all       1772       1785      0.686      0.658       0.72      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/120      15.3G     0.4639     0.8149       1.09         31        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.648      0.689      0.718      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/120      15.4G     0.4637     0.8035      1.088         29        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.656      0.687      0.714       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/120      15.5G     0.4599     0.7831      1.085         35        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.654      0.695      0.718      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/120      15.6G     0.4586     0.7926      1.082         39        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.1s
#                    all       1772       1785      0.668      0.675      0.721      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/120      15.7G     0.4599     0.7839      1.085         38        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.652      0.708      0.727      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/120      15.8G     0.4536     0.7817      1.082         37        640: 100% ━━━━━━━━━━━━ 195/195 4.8it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.659      0.691      0.727      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/120        16G     0.4514     0.7802      1.084         36        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.645      0.712      0.726       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/120        16G     0.4544     0.7757       1.08         37        640: 100% ━━━━━━━━━━━━ 195/195 4.9it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all       1772       1785      0.681      0.672      0.721      0.654
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 59, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 79 epochs completed in 1.076 hours.
# Optimizer stripped from /content/emotion_detection_yolov9_comparison/yolov9m_train_results/weights/last.pt, 40.8MB
# Optimizer stripped from /content/emotion_detection_yolov9_comparison/yolov9m_train_results/weights/best.pt, 40.8MB
#
# Validating /content/emotion_detection_yolov9_comparison/yolov9m_train_results/weights/best.pt...
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9m summary (fused): 151 layers, 20,018,776 parameters, 0 gradients, 76.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 2.9it/s 9.6s
#                    all       1772       1785      0.701      0.685      0.745      0.674
#                  anger        242        243      0.688       0.56      0.671      0.571
#                content        239        239      0.841      0.684      0.797      0.746
#                disgust        207        207      0.645      0.556       0.63      0.573
#                   fear        199        199      0.747      0.678      0.796      0.712
#                  happy        215        218      0.841      0.885      0.929      0.857
#                neutral        261        261      0.601      0.697      0.699      0.632
#                    sad        219        219      0.575      0.772      0.707      0.634
#               surprise        199        199      0.672      0.648      0.727      0.666
# Speed: 0.1ms preprocess, 2.1ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/emotion_detection_yolov9_comparison/yolov9m_train_results

# %% [markdown]
# ### Validation

# %%
model_m_val = YOLO("/content/emotion_detection_yolov9_comparison/yolov9m_train_results/weights/best.pt")

# %%
val_m_result = model_m_val.val(
    data=data_path,
    project=project_name,
    name="yolov9m_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9m summary (fused): 151 layers, 20,018,776 parameters, 0 gradients, 76.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1141.3±386.3 MB/s, size: 37.7 KB)
# val: Scanning /content/dataset/New-Human-Face-Detections/valid/labels.cache... 1772 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1772/1772 2.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 3.0it/s 18.4s
#                    all       1772       1785      0.702      0.684      0.745      0.673
#                  anger        242        243      0.688      0.554      0.671       0.57
#                content        239        239       0.84      0.686      0.798      0.745
#                disgust        207        207      0.644      0.556      0.629      0.571
#                   fear        199        199      0.746      0.678      0.796      0.712
#                  happy        215        218      0.839      0.883      0.931      0.858
#                neutral        261        261      0.603      0.697      0.699      0.631
#                    sad        219        219      0.577      0.772      0.708      0.635
#               surprise        199        199      0.677      0.643      0.727      0.665
# Speed: 0.8ms preprocess, 3.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Saving /content/emotion_detection_yolov9_comparison/yolov9m_validation_results/predictions.json...
# Results saved to /content/emotion_detection_yolov9_comparison/yolov9m_validation_results

# %% [markdown]
# ### Testing

# %%
model_m_test = YOLO("/content/emotion_detection_yolov9_comparison/yolov9m_train_results/weights/best.pt")

# %%
test_m_result = model_m_test.val(
    data=data_path,
    project=project_name,
    name="yolov9m_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9m summary (fused): 151 layers, 20,018,776 parameters, 0 gradients, 76.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1251.1±416.5 MB/s, size: 44.4 KB)
# val: Scanning /content/dataset/New-Human-Face-Detections/test/labels... 891 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 891/891 1.6Kit/s 0.6s
# val: New cache created: /content/dataset/New-Human-Face-Detections/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 2.8it/s 10.1s
#                    all        891        896       0.58      0.696      0.681      0.617
#                  anger        121        121      0.602      0.562      0.593      0.506
#                content        120        120      0.684       0.65      0.738      0.692
#                disgust        104        104       0.54      0.565      0.584      0.527
#                   fear        100        100      0.649      0.591      0.672      0.603
#                  happy        108        112      0.666      0.911      0.892      0.825
#                neutral        130        130       0.46      0.815      0.645      0.589
#                    sad        110        110      0.464      0.694      0.594      0.533
#               surprise         99         99      0.578      0.778      0.728      0.656
# Speed: 1.1ms preprocess, 3.0ms inference, 0.0ms loss, 0.9ms postprocess per image
# Saving /content/emotion_detection_yolov9_comparison/yolov9m_testing_results/predictions.json...
# Results saved to /content/emotion_detection_yolov9_comparison/yolov9m_testing_results

# %% [markdown]
# ## Save Results

# %%
# !mkdir -p /content/drive/MyDrive/YOLO-Dataset/YOLO-Results
# !cp -r /content/emotion_detection_yolov9_comparison /content/drive/MyDrive/YOLO-Dataset/YOLO-Results
