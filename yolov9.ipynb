# %% [markdown]
# # YOLOv9 Experiments

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/New-Revised-Emotions-Detection.7z'

# %%
# !cp {zip_dataset_path} /content/

# %%
!7z x /content/New-Revised-Emotions-Detection.7z -o/content/dataset/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 346622586 bytes (331 MiB)
#
# Extracting archive: /content/New-Revised-Emotions-Detection.7z
# --
# Path = /content/New-Revised-Emotions-Detection.7z
# Type = 7z
# Physical Size = 346622586
# Headers Size = 397374
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 10
# Files: 17769
# Size:       352299353
# Compressed: 346622586

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.4 MB/s eta 0:00:00
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)  # type: ignore
# Out:
# CUDA available: True
# Device name: NVIDIA A100-SXM4-40GB
# CUDA version: 12.6

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Dataset YAML Path
data_path = "/content/dataset/New-Revised-Emotions-Detection/data.yaml"

# Project Name
project_name = "emotion_detection_yolov9_comparison"

# %%
# Training Parameter
train_params = {
    "epochs": 120,
    "patience": 20,
    "batch": 32,
    "imgsz": 640,
    "save": True,
    "save_period": 20,
    "device": 0,
    "pretrained":True,
    "optimizer": "AdamW",
    "seed": 3407,
    "cos_lr": True,
    "close_mosaic": True,
    "lr0": 0.001,
    "lrf": 0.02,
    "momentum": 0.9,
    "val": True,
    "plots": True,

    # Augmentations
    "hsv_h": 0.015, # Variasi Random Color
    "hsv_s": 0.7,   # Saturation Randomness
    "hsv_v": 0.4,   # Brightness Randomness
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
}

# %%
# Validation Parameter
val_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'val',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %%
# Testing Parameter
test_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'test',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %% [markdown]
# ## YOLOv9t (Tiny Size)

# %% [markdown]
# ### Train

# %%
model_t = YOLO("yolov9t.pt")

# %%
t_result = model_t.train(
    data=data_path,
    project=project_name,
    name="yolov9t_train_results",
    **train_params
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_t_val = YOLO("/content/emotion_detection_yolov9_comparison/yolov9t_train_results/weights/best.pt")

# %%
val_n_result = model_t_val.val(
    data=data_path,
    project=project_name,
    name="yolov9t_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9t summary (fused): 197 layers, 1,972,344 parameters, 0 gradients, 7.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 927.6±426.5 MB/s, size: 37.7 KB)
# val: Scanning /content/dataset/New-Revised-Emotions-Detection/valid/labels.cache... 1772 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1772/1772 2.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 3.4it/s 16.5s
#                    all       1772       1785      0.685      0.721      0.771      0.701
#                  anger        242        243      0.644      0.654      0.744      0.634
#                content        239        239      0.731      0.724      0.818      0.771
#                disgust        207        207      0.677      0.565      0.655      0.601
# ...

# %% [markdown]
# ### Testing

# %%
model_t_test = YOLO("/content/emotion_detection_yolov9_comparison/yolov9t_train_results/weights/best.pt")

# %%
test_t_result = model_t_test.val(
    data=data_path,
    project=project_name,
    name="yolov9t_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9t summary (fused): 197 layers, 1,972,344 parameters, 0 gradients, 7.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 784.4±200.8 MB/s, size: 44.4 KB)
# val: Scanning /content/dataset/New-Revised-Emotions-Detection/test/labels... 891 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 891/891 1.5Kit/s 0.6s
# val: New cache created: /content/dataset/New-Revised-Emotions-Detection/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.1it/s 9.1s
#                    all        891        896      0.604      0.738      0.735      0.667
#                  anger        121        121      0.575      0.678      0.688      0.585
#                content        120        120      0.617      0.758       0.76      0.712
# ...

# %% [markdown]
# ## YOLOv9s (Small Size)

# %% [markdown]
# ### Train

# %%
model_s = YOLO("yolov9s.pt")

# %%
s_result = model_s.train(
    data=data_path,
    project=project_name,
    name="yolov9s_train_results",
    **train_params
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_s_val = YOLO("/content/emotion_detection_yolov9_comparison/yolov9s_train_results/weights/best.pt")

# %%
val_s_result = model_s_val.val(
    data=data_path,
    project=project_name,
    name="yolov9s_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9s summary (fused): 197 layers, 7,170,184 parameters, 0 gradients, 26.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 962.7±417.4 MB/s, size: 39.3 KB)
# val: Scanning /content/dataset/New-Revised-Emotions-Detection/valid/labels.cache... 1772 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1772/1772 3.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 3.3it/s 17.0s
#                    all       1772       1785      0.672      0.735      0.761      0.694
#                  anger        242        243      0.596      0.741      0.712      0.615
#                content        239        239      0.748      0.684      0.798      0.746
#                disgust        207        207      0.611      0.636      0.659      0.609
# ...

# %% [markdown]
# ### Testing

# %%
model_s_test = YOLO("/content/emotion_detection_yolov9_comparison/yolov9s_train_results/weights/best.pt")

# %%
test_s_result = model_s_test.val(
    data=data_path,
    project=project_name,
    name="yolov9s_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9s summary (fused): 197 layers, 7,170,184 parameters, 0 gradients, 26.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1026.1±308.5 MB/s, size: 41.1 KB)
# val: Scanning /content/dataset/New-Revised-Emotions-Detection/test/labels.cache... 891 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 891/891 2.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 3.0it/s 9.4s
#                    all        891        896      0.665       0.65      0.726      0.662
#                  anger        121        121      0.572      0.628      0.659      0.565
#                content        120        120      0.723      0.617      0.758       0.71
#                disgust        104        104       0.66      0.452      0.621      0.571
# ...

# %% [markdown]
# ## YOLOv9m (Medium Size)

# %% [markdown]
# ### Train

# %%
model_m = YOLO("yolov9m.pt")

# %%
m_result = model_m.train(
    data=data_path,
    project=project_name,
    name="yolov9m_train_results",
    **train_params
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_m_val = YOLO("/content/emotion_detection_yolov9_comparison/yolov9m_train_results/weights/best.pt")

# %%
val_m_result = model_m_val.val(
    data=data_path,
    project=project_name,
    name="yolov9m_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9m summary (fused): 151 layers, 20,018,776 parameters, 0 gradients, 76.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1120.9±371.7 MB/s, size: 37.7 KB)
# val: Scanning /content/dataset/New-Revised-Emotions-Detection/valid/labels.cache... 1772 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1772/1772 2.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 3.1it/s 18.3s
#                    all       1772       1785      0.669       0.77      0.781      0.713
#                  anger        242        243      0.604      0.761      0.741      0.641
#                content        239        239      0.739      0.745      0.819      0.766
#                disgust        207        207      0.645      0.659      0.693      0.643
# ...

# %% [markdown]
# ### Testing

# %%
model_m_test = YOLO("/content/emotion_detection_yolov9_comparison/yolov9m_train_results/weights/best.pt")

# %%
test_m_result = model_m_test.val(
    data=data_path,
    project=project_name,
    name="yolov9m_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9m summary (fused): 151 layers, 20,018,776 parameters, 0 gradients, 76.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1202.3±495.8 MB/s, size: 44.4 KB)
# val: Scanning /content/dataset/New-Revised-Emotions-Detection/test/labels... 891 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 891/891 1.6Kit/s 0.6s
# val: New cache created: /content/dataset/New-Revised-Emotions-Detection/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 2.8it/s 9.9s
#                    all        891        896      0.618       0.68      0.704       0.64
#                  anger        121        121      0.544       0.62      0.667      0.573
#                content        120        120      0.705      0.717      0.741      0.698
# ...

# %% [markdown]
# ## Save Results

# %%
# !mkdir -p /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Revised
# !cp -r /content/emotion_detection_yolov9_comparison /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Revised
