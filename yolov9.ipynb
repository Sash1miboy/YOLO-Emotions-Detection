# %% [markdown]
# # YOLOv9 Experiments

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/processed_emotions_dataset.7z'

# %%
# !cp {zip_dataset_path} /content/

# %%
!7z x /content/processed_emotions_dataset.7z -o/content/dataset/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 346608580 bytes (331 MiB)
#
# Extracting archive: /content/processed_emotions_dataset.7z
# --
# Path = /content/processed_emotions_dataset.7z
# Type = 7z
# Physical Size = 346608580
# Headers Size = 399775
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 10
# Files: 17769
# Size:       352299356
# Compressed: 346608580

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.7 MB/s eta 0:00:00
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)  # type: ignore
# Out:
# CUDA available: True
# Device name: NVIDIA A100-SXM4-40GB
# CUDA version: 12.6

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Dataset YAML Path
data_path = "/content/dataset/processed_emotions_dataset/data.yaml"

# Project Name
project_name = "emotion_detection_yolo_comparison"

# %%
# Training Parameter
train_params = {
    "epochs": 120,
    "patience": 20,
    "batch": 32,
    "imgsz": 640,
    "save": True,
    "save_period": 20,
    "device": 0,
    "pretrained":True,
    "optimizer": "AdamW",
    "seed": 3407,
    "cos_lr": True,
    "close_mosaic": True,
    "freeze": 5,
    "lr0": 0.0001,
    "lrf": 0.01,
    "momentum": 0.9,
    "val": True,
    "plots": True,

    # Augmentations
    "hsv_h": 0.015, # Variasi Random Color
    "hsv_s": 0.7,   # Saturation Randomness
    "hsv_v": 0.4,   # Brightness Randomness
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
}

# %%
# Validation Parameter
val_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'val',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %%
# Testing Parameter
test_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'test',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %% [markdown]
# ## YOLOv9t (Tiny Size)

# %% [markdown]
# ### Train

# %%
model_t = YOLO("yolov9t.pt")

# %%
t_result = model_t.train(
    data=data_path,
    project=project_name,
    name="yolov9t_train_results",
    **train_params
)

# %% [markdown]
# ### Validation

# %%
model_t_val = YOLO("path/to/best.pt")

# %%
val_n_result = model_t_val.val(
    data=data_path,
    project=project_name,
    name="yolov9t_validation_results",
    **val_params
)

# %% [markdown]
# ### Testing

# %%
model_t_test = YOLO("path/to/best.pt")

# %%
test_t_result = model_t_test.val(
    data=data_path,
    project=project_name,
    name="yolov9t_testing_results",
    **test_params
)

# %% [markdown]
# ## YOLOv9s (Small Size)

# %% [markdown]
# ### Train

# %%
model_s = YOLO("yolov9s.pt")

# %%
s_result = model_s.train(
    data=data_path,
    project=project_name,
    name="yolov9s_train_results",
    **train_params
)

# %% [markdown]
# ### Validation

# %%
model_s_val = YOLO("path/to/best.pt")

# %%
val_s_result = model_s_val.val(
    data=data_path,
    project=project_name,
    name="yolov9s_validation_results",
    **val_params
)

# %% [markdown]
# ### Testing

# %%
model_s_test = YOLO("path/to/best.pt")

# %%
test_s_result = model_s_test.val(
    data=data_path,
    project=project_name,
    name="yolov9s_testing_results",
    **test_params
)

# %% [markdown]
# ## YOLOv9m (Medium Size)

# %% [markdown]
# ### Train

# %%
model_m = YOLO("yolov9m.pt")

# %%
m_result = model_m.train(
    data=data_path,
    project=project_name,
    name="yolov9m_train_results",
    **train_params
)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_m_val = YOLO("/content/emotion_detection_yolo_comparison/yolov9m_train_results/weights/best.pt")

# %%
val_m_result = model_m_val.val(
    data=data_path,
    project=project_name,
    name="yolov9m_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9m summary (fused): 151 layers, 20,018,776 parameters, 0 gradients, 76.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1252.1±413.2 MB/s, size: 36.6 KB)
# val: Scanning /content/dataset/processed_emotions_dataset/valid/labels.cache... 891 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 891/891 1.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 2.4it/s 11.7s
#                    all        891        896      0.573      0.709      0.699      0.624
#                  anger        121        121      0.492      0.826      0.702      0.585
#                content        120        120      0.582      0.733      0.734      0.677
#                disgust        104        104      0.552      0.581      0.628      0.575
# ...

# %% [markdown]
# ### Testing

# %%
model_m_test = YOLO("/content/emotion_detection_yolo_comparison/yolov9m_train_results/weights/best.pt")

# %%
test_m_result = model_m_test.val(
    data=data_path,
    project=project_name,
    name="yolov9m_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv9m summary (fused): 151 layers, 20,018,776 parameters, 0 gradients, 76.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 854.2±352.4 MB/s, size: 38.4 KB)
# val: Scanning /content/dataset/processed_emotions_dataset/test/labels... 1772 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1772/1772 1.5Kit/s 1.2s
# val: New cache created: /content/dataset/processed_emotions_dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 2.5it/s 22.1s
#                    all       1772       1785      0.652      0.717      0.741      0.661
#                  anger        242        243      0.479      0.811       0.71       0.61
#                content        239        239      0.676      0.766      0.793      0.723
# ...

# %% [markdown]
# ## Save Results

# %%
# !mkdir -p /content/drive/MyDrive/YOLO-Dataset/YOLO-Results
# !cp -r /content/emotion_detection_yolo_comparison /content/drive/MyDrive/YOLO-Dataset/YOLO-Results
