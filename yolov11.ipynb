# %% [markdown]
# # YOLOv11 Experiments

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/New-Revised-Emotions-Detection.7z'
# zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/FER-2013-YOLO-Format-Preprocessed.7z'
zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/AffectNet-YOLO-Format-Preprocessed.7z'

# %%
# !cp {zip_dataset_path} /content/

# %%
# !7z x /content/New-Revised-Emotions-Detection.7z -o/content/dataset/
!7z x /content/AffectNet-YOLO-Format-Preprocessed.7z -o/content/dataset/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 57369604 bytes (55 MiB)
#
# Extracting archive: /content/AffectNet-YOLO-Format-Preprocessed.7z
# --
# Path = /content/AffectNet-YOLO-Format-Preprocessed.7z
# Type = 7z
# Physical Size = 57369604
# Headers Size = 1112896
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 10
# Files: 48419
# Size:       71522198
# Compressed: 57369604

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 82.0 MB/s eta 0:00:00
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)  # type: ignore
# Out:
# CUDA available: True
# Device name: NVIDIA A100-SXM4-40GB
# CUDA version: 12.8

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Dataset YAML Path
data_path = r"/content/dataset/AffectNet-YOLO-Format-Preprocessed/data.yaml"

# Project Name
# project_name = "emotion_detection_yolov11_comparison"
project_name = "/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov11_comparison"

# %%
# Training Parameter
train_params = {
    "epochs": 120,
    "patience": 20,
    "batch": 32,
    "imgsz": 640,
    "save": True,
    "save_period": 20,
    "device": 0,
    "pretrained":True,
    "optimizer": "AdamW",
    "seed": 3407,
    "cos_lr": True,
    "close_mosaic": 20,
    "lr0": 0.001,
    "lrf": 0.02,
    "momentum": 0.9,
    "val": True,
    "plots": True,

    # Augmentations
    "hsv_h": 0.015, # Variasi Random Color
    "hsv_s": 0.7,   # Saturation Randomness
    "hsv_v": 0.4,   # Brightness Randomness
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
    "mixup": 0.0
}

# %%
# Validation Parameter
val_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'val',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %%
# Testing Parameter
test_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'test',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %% [markdown]
# ## YOLOv11n (Nano Size)

# %% [markdown]
# ### Train

# %%
model_n = YOLO("yolo11n.pt")

# %%
n_result = model_n.train(
    data=data_path,
    project=project_name,
    name="yolov11n_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_n_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov11_comparison/yolov11n_train_results/weights/best.pt")

# %%
val_n_result = model_n_val.val(
    data=data_path,
    project=project_name,
    name="yolov11n_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLO11n summary (fused): 101 layers, 2,583,712 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 153.6±60.6 MB/s, size: 2.9 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 1.7Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 2.2it/s 1:10
#                    all       4843       4843      0.699      0.773      0.814       0.71
#                  Anger        653        653      0.671      0.764      0.797      0.674
#               Contempt        577        577      0.728      0.799      0.848      0.758
#                Disgust        606        606      0.694      0.657      0.761      0.659
# ...

# %% [markdown]
# ### Testing

# %%
model_n_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov11_comparison/yolov11n_train_results/weights/best.pt")

# %%
test_n_result = model_n_test.val(
    data=data_path,
    project=project_name,
    name="yolov11n_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLO11n summary (fused): 101 layers, 2,583,712 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 126.2±40.2 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 1.5Kit/s 1.6s
# val: New cache created: /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 2.1it/s 36.4s
#                    all       2421       2421      0.705      0.751      0.796      0.697
#                  Anger        327        327      0.705      0.762      0.803      0.694
#               Contempt        288        288       0.73      0.778      0.807      0.723
# ...

# %% [markdown]
# ## YOLOv11s (Small Size)

# %% [markdown]
# ### Train

# %%
model_s = YOLO("yolo11s.pt")

# %%
s_result = model_s.train(
    data=data_path,
    project=project_name,
    name="yolov11s_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_s_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/emotion_detection_yolov11_comparison/yolov11s_train_results2/weights/best.pt")

# %%
val_s_result = model_s_val.val(
    data=data_path,
    project=project_name,
    name="yolov11s_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 101 layers, 9,415,509 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 99.8±35.8 MB/s, size: 1.8 KB)
# val: Scanning /content/dataset/FER-2013-YOLO-Format-Preprocessed/valid/labels.cache... 6600 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6600/6600 2.1Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 207/207 2.4it/s 1:28
#                    all       6600       6600      0.632      0.679      0.692      0.541
#                  angry        920        920      0.598       0.59      0.642      0.497
#                disgust         86         86      0.577      0.581      0.616      0.456
#                   fear        908        908      0.489      0.533      0.548      0.428
# ...

# %% [markdown]
# ### Testing

# %%
model_s_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/emotion_detection_yolov11_comparison/yolov11s_train_results2/weights/best.pt")

# %%
test_s_result = model_s_test.val(
    data=data_path,
    project=project_name,
    name="yolov11s_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 101 layers, 9,415,509 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 82.7±29.1 MB/s, size: 1.8 KB)
# val: Scanning /content/dataset/FER-2013-YOLO-Format-Preprocessed/test/labels... 3300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3300/3300 1.5Kit/s 2.2s
# val: New cache created: /content/dataset/FER-2013-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 104/104 2.3it/s 46.0s
#                    all       3300       3300      0.599       0.68      0.658      0.518
#                  angry        460        460      0.589       0.67      0.642      0.502
#                disgust         43         43      0.482      0.512      0.418      0.308
# ...

# %% [markdown]
# ## YOLOv11m (Medium Size)

# %% [markdown]
# ### Train

# %%
model_m = YOLO("yolo11m.pt")

# %%
m_result = model_m.train(
    data=data_path,
    project=project_name,
    name="yolov11m_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_m_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/emotion_detection_yolov11_comparison/yolov11m_train_results/weights/best.pt")

# %%
val_m_result = model_m_val.val(
    data=data_path,
    project=project_name,
    name="yolov11m_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11m summary (fused): 126 layers, 20,035,429 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 97.3±40.1 MB/s, size: 1.9 KB)
# val: Scanning /content/dataset/FER-2013-YOLO-Format-Preprocessed/valid/labels.cache... 6600 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6600/6600 2.8Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 207/207 2.2it/s 1:36
#                    all       6600       6600      0.626       0.67      0.681      0.534
#                  angry        920        920      0.574      0.624      0.648      0.509
#                disgust         86         86       0.56      0.488      0.534      0.378
#                   fear        908        908      0.487      0.508      0.528      0.413
# ...

# %% [markdown]
# ### Testing

# %%
model_m_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/emotion_detection_yolov11_comparison/yolov11m_train_results/weights/best.pt")

# %%
test_m_result = model_m_test.val(
    data=data_path,
    project=project_name,
    name="yolov11m_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11m summary (fused): 126 layers, 20,035,429 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 85.3±29.4 MB/s, size: 1.8 KB)
# val: Scanning /content/dataset/FER-2013-YOLO-Format-Preprocessed/test/labels... 3300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3300/3300 1.6Kit/s 2.1s
# val: New cache created: /content/dataset/FER-2013-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 104/104 2.1it/s 50.4s
#                    all       3300       3300      0.629      0.649      0.657      0.518
#                  angry        460        460      0.584      0.607      0.642      0.503
#                disgust         43         43      0.555      0.465      0.407      0.289
# ...

# %% [markdown]
# ## YOLOv11l (Large Size)

# %% [markdown]
# ### Train

# %%
model_l = YOLO("yolo11l.pt")

# %%
l_result = model_l.train(
    data=data_path,
    project=project_name,
    name="yolov11l_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_l_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/emotion_detection_yolov11_comparison/yolov11l_train_results/weights/best.pt")

# %%
val_l_result = model_l_val.val(
    data=data_path,
    project=project_name,
    name="yolov11l_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11l summary (fused): 191 layers, 25,284,709 parameters, 0 gradients, 86.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 106.9±43.2 MB/s, size: 1.9 KB)
# val: Scanning /content/dataset/FER-2013-YOLO-Format-Preprocessed/valid/labels.cache... 6600 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6600/6600 2.3Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 207/207 2.0it/s 1:44
#                    all       6600       6600      0.588      0.688      0.667      0.525
#                  angry        920        920      0.553      0.648      0.645      0.499
#                disgust         86         86      0.481       0.43      0.422      0.308
#                   fear        908        908      0.457      0.553      0.524       0.41
# ...

# %% [markdown]
# ### Testing

# %%
model_l_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/emotion_detection_yolov11_comparison/yolov11l_train_results/weights/best.pt")

# %%
test_l_result = model_l_test.val(
    data=data_path,
    project=project_name,
    name="yolov11l_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11l summary (fused): 191 layers, 25,284,709 parameters, 0 gradients, 86.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 88.3±28.1 MB/s, size: 1.8 KB)
# val: Scanning /content/dataset/FER-2013-YOLO-Format-Preprocessed/test/labels... 3300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3300/3300 1.6Kit/s 2.1s
# val: New cache created: /content/dataset/FER-2013-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 104/104 1.9it/s 54.4s
#                    all       3300       3300      0.549      0.724      0.657      0.518
#                  angry        460        460      0.524       0.72      0.666      0.518
#                disgust         43         43      0.354      0.442      0.368       0.27
# ...

# %% [markdown]
# ## Save Results

# %%
# !mkdir -p /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed
# !cp -r //content/emotion_detection_yolov11_comparison /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed
