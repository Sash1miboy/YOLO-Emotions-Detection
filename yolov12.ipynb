# %% [markdown]
# # YOLOv12 Experiments

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/New-Revised-Emotions-Detection.7z'
# zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/FER-2013-YOLO-Format-Preprocessed.7z'
zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/AffectNet-YOLO-Format-Preprocessed.7z'

# %%
# !cp {zip_dataset_path} /content/

# %%
# !7z x /content/New-Revised-Emotions-Detection.7z -o/content/dataset/
!7z x /content/AffectNet-YOLO-Format-Preprocessed.7z -o/content/dataset/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 57369604 bytes (55 MiB)
#
# Extracting archive: /content/AffectNet-YOLO-Format-Preprocessed.7z
# --
# Path = /content/AffectNet-YOLO-Format-Preprocessed.7z
# Type = 7z
# Physical Size = 57369604
# Headers Size = 1112896
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 10
# Files: 48419
# Size:       71522198
# Compressed: 57369604

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.6 MB/s eta 0:00:00
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)  # type: ignore
# Out:
# CUDA available: True
# Device name: NVIDIA A100-SXM4-40GB
# CUDA version: 12.8

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Dataset YAML Path
data_path = r"/content/dataset/AffectNet-YOLO-Format-Preprocessed/data.yaml"

# Project Name
# project_name = "emotion_detection_yolov12_comparison"
project_name = "/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison"

# %%
# Training Parameter
train_params = {
    "epochs": 120,
    "patience": 20,
    "batch": 32,
    "imgsz": 640,
    "save": True,
    "save_period": 20,
    "device": 0,
    "pretrained":True,
    "optimizer": "AdamW",
    "seed": 3407,
    "cos_lr": True,
    "close_mosaic": 20,
    "lr0": 0.001,
    "lrf": 0.02,
    "momentum": 0.9,
    "val": True,
    "plots": True,

    # Augmentations
    "hsv_h": 0.015, # Variasi Random Color
    "hsv_s": 0.7,   # Saturation Randomness
    "hsv_v": 0.4,   # Brightness Randomness
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
    "mixup": 0.0,
}

# %%
# Validation Parameter
val_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'val',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %%
# Testing Parameter
test_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'test',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %% [markdown]
# ## YOLOv12n (Nano Size)

# %% [markdown]
# ### Train

# %%
model_n = YOLO("yolo12n.pt")

# %%
n_result = model_n.train(
    data=data_path,
    project=project_name,
    name="yolov12n_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.17 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_n_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12n_train_results/weights/best.pt")

# %%
val_n_result = model_n_val.val(
    data=data_path,
    project=project_name,
    name="yolov12n_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.17 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12n summary (fused): 159 layers, 2,558,288 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 133.7±50.4 MB/s, size: 2.9 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 2.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 2.1it/s 1:14
#                    all       4843       4843      0.731      0.759      0.822      0.716
#                  Anger        653        653      0.696      0.752      0.808      0.686
#               Contempt        577        577      0.764      0.757      0.854      0.761
#                Disgust        606        606       0.72      0.677      0.762       0.66
# ...

# %% [markdown]
# ### Testing

# %%
model_n_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12n_train_results/weights/best.pt")

# %%
test_n_result = model_n_test.val(
    data=data_path,
    project=project_name,
    name="yolov12n_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.17 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12n summary (fused): 159 layers, 2,558,288 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 129.4±38.6 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 1.5Kit/s 1.7s
# val: New cache created: /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 2.0it/s 38.2s
#                    all       2421       2421      0.708       0.75      0.807      0.707
#                  Anger        327        327      0.704      0.758      0.812      0.701
#               Contempt        288        288      0.752      0.758      0.826      0.738
# ...

# %% [markdown]
# ## YOLOv12s (Small Size)

# %% [markdown]
# ### Train

# %%
model_s = YOLO("yolo12s.pt")

# %%
s_result = model_s.train(
    data=data_path,
    project=project_name,
    name="yolov12s_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.17 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_s_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12s_train_results/weights/best.pt")

# %%
val_s_result = model_s_val.val(
    data=data_path,
    project=project_name,
    name="yolov12s_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.17 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12s summary (fused): 159 layers, 9,233,976 parameters, 0 gradients, 21.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 164.4±51.5 MB/s, size: 3.0 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 2.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 1.9it/s 1:18
#                    all       4843       4843       0.72      0.781      0.831      0.726
#                  Anger        653        653      0.699      0.766      0.811       0.69
#               Contempt        577        577      0.765      0.778      0.859      0.764
#                Disgust        606        606      0.715      0.689      0.776      0.674
# ...

# %% [markdown]
# ### Testing

# %%
model_s_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12s_train_results/weights/best.pt")

# %%
test_s_result = model_s_test.val(
    data=data_path,
    project=project_name,
    name="yolov12s_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.17 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12s summary (fused): 159 layers, 9,233,976 parameters, 0 gradients, 21.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 158.1±46.3 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 923.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 1.8it/s 41.4s
#                    all       2421       2421      0.699      0.768      0.813      0.712
#                  Anger        327        327      0.704      0.768      0.823      0.709
#               Contempt        288        288      0.746       0.75      0.841       0.75
#                Disgust        303        303      0.679       0.63      0.742      0.643
# ...

# %% [markdown]
# ## YOLOv12m (Medium Size)

# %% [markdown]
# ### Train

# %%
model_m = YOLO("yolo12m.pt")

# %%
m_result = model_m.train(
    data=data_path,
    project=project_name,
    name="yolov12m_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.17 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_m_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12m_train_results/weights/best.pt")

# %%
val_m_result = model_m_val.val(
    data=data_path,
    project=project_name,
    name="yolov12m_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12m summary (fused): 169 layers, 20,111,080 parameters, 0 gradients, 67.1 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 96.7±33.9 MB/s, size: 2.9 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 1.5Kit/s 3.2s
# val: New cache created: /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 1.8it/s 1:26
#                    all       4843       4843      0.726      0.762      0.819      0.713
#                  Anger        653        653      0.692       0.74      0.803      0.687
#               Contempt        577        577      0.775      0.749      0.853      0.756
# ...

# %% [markdown]
# ### Testing

# %%
model_m_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12m_train_results/weights/best.pt")

# %%
test_m_result = model_m_test.val(
    data=data_path,
    project=project_name,
    name="yolov12m_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12m summary (fused): 169 layers, 20,111,080 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 101.8±37.9 MB/s, size: 2.5 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 1.6Kit/s 1.6s
# val: New cache created: /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 1.7it/s 43.8s
#                    all       2421       2421      0.696      0.766      0.807      0.704
#                  Anger        327        327      0.674      0.777      0.805      0.693
#               Contempt        288        288      0.738       0.75      0.828      0.738
# ...

# %% [markdown]
# ## YOLOv12l (Large Size)

# %% [markdown]
# ### Train

# %%
model_l = YOLO("yolo12l.pt")

# %%
l_result = model_l.train(
    data=data_path,
    project=project_name,
    name="yolov12l_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Resume

# %%
last_pt = "/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/emotion_detection_yolov12_comparison/yolov12l_train_results/weights/last.pt"

# %%
model_l = YOLO(last_pt)

# %%
model_l.train(resume=True)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_l_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12l_train_results/weights/best.pt")

# %%
val_l_result = model_l_val.val(
    data=data_path,
    project=project_name,
    name="yolov12l_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12l summary (fused): 283 layers, 26,345,240 parameters, 0 gradients, 88.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 158.1±54.1 MB/s, size: 3.0 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 1.5it/s 1:39
#                    all       4843       4843      0.706      0.769      0.814      0.706
#                  Anger        653        653      0.656      0.773      0.797       0.68
#               Contempt        577        577      0.745      0.792      0.856      0.757
#                Disgust        606        606      0.674      0.683      0.745      0.646
# ...

# %% [markdown]
# ### Testing

# %%
model_l_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov12_comparison/yolov12l_train_results/weights/best.pt")

# %%
test_l_result = model_l_test.val(
    data=data_path,
    project=project_name,
    name="yolov12l_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv12l summary (fused): 283 layers, 26,345,240 parameters, 0 gradients, 88.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 154.2±48.0 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 1.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 1.5it/s 51.4s
#                    all       2421       2421      0.663      0.768      0.788      0.687
#                  Anger        327        327      0.653      0.798      0.794       0.68
#               Contempt        288        288      0.694      0.771      0.799      0.714
#                Disgust        303        303      0.582      0.597      0.687      0.592
# ...

# %% [markdown]
# ## Save Results

# %%
# !mkdir -p /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed
# !cp -r /content/emotion_detection_yolov12_comparison /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed
