# %% [markdown]
# # YOLOv10 Experiments

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/New-Revised-Emotions-Detection.7z'
# zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/FER-2013-YOLO-Format-Preprocessed.7z'
zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/AffectNet-YOLO-Format-Preprocessed.7z'

# %%
# !cp {zip_dataset_path} /content/

# %%
# !7z x /content/New-Revised-Emotions-Detection.7z -o/content/dataset/
# !7z x /content/FER-2013-YOLO-Format-Preprocessed.7z -o/content/dataset/
!7z x /content/AffectNet-YOLO-Format-Preprocessed.7z -o/content/dataset/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 57369604 bytes (55 MiB)
#
# Extracting archive: /content/AffectNet-YOLO-Format-Preprocessed.7z
# --
# Path = /content/AffectNet-YOLO-Format-Preprocessed.7z
# Type = 7z
# Physical Size = 57369604
# Headers Size = 1112896
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 10
# Files: 48419
# Size:       71522198
# Compressed: 57369604

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.7 MB/s eta 0:00:00
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)  # type: ignore
# Out:
# CUDA available: True
# Device name: NVIDIA A100-SXM4-40GB
# CUDA version: 12.8

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Dataset YAML Path
data_path = r"/content/dataset/AffectNet-YOLO-Format-Preprocessed/data.yaml"

# Project Name
# project_name = "emotion_detection_fer2013_yolov10_comparison"
project_name = "/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison"

# %%
# Training Parameter
train_params = {
    "epochs": 120,
    "patience": 20,
    "batch": 32,
    "imgsz": 640,
    "save": True,
    "save_period": 20,
    "device": 0,
    "pretrained":True,
    "optimizer": "AdamW",
    "seed": 3407,
    "cos_lr": True,
    "close_mosaic": 20,
    "lr0": 0.001,
    "lrf": 0.02,
    "momentum": 0.9,
    "val": True,
    "plots": True,

    # Augmentations
    "hsv_h": 0.015, # Variasi Random Color
    "hsv_s": 0.7,   # Saturation Randomness
    "hsv_v": 0.4,   # Brightness Randomness
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
    "mixup": 0.0,
}

# %%
# Validation Parameter
val_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'val',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %%
# Testing Parameter
test_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'test',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %% [markdown]
# ## YOLOv10n (Nano Size)

# %% [markdown]
# ### Train

# %%
model_n = YOLO("yolov10n.pt")

# %%
n_result = model_n.train(
    data=data_path,
    project=project_name,
    name="yolov10n_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_n_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10n_train_results/weights/best.pt")

# %%
val_n_result = model_n_val.val(
    data=data_path,
    project=project_name,
    name="yolov10n_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10n summary (fused): 102 layers, 2,266,728 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 144.0±45.7 MB/s, size: 2.9 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 2.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 2.3it/s 1:06
#                    all       4843       4843      0.717      0.768      0.819      0.713
#                  Anger        653        653      0.687      0.749      0.801      0.682
#               Contempt        577        577      0.763      0.766      0.848      0.755
#                Disgust        606        606      0.693      0.677      0.764      0.661
# ...

# %% [markdown]
# ### Testing

# %%
model_n_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10n_train_results/weights/best.pt")

# %%
test_n_result = model_n_test.val(
    data=data_path,
    project=project_name,
    name="yolov10n_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10n summary (fused): 102 layers, 2,266,728 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 103.8±46.8 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 1.6Kit/s 1.5s
# val: New cache created: /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 2.2it/s 34.9s
#                    all       2421       2421      0.674      0.763      0.797      0.696
#                  Anger        327        327      0.698      0.783      0.814      0.698
#               Contempt        288        288      0.696      0.753      0.814      0.728
# ...

# %% [markdown]
# ## YOLOv10s (Small Size)

# %% [markdown]
# ### Train

# %%
model_s = YOLO("yolov10s.pt")

# %%
s_result = model_s.train(
    data=data_path,
    project=project_name,
    name="yolov10s_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_s_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10s_train_results/weights/best.pt")

# %%
val_s_result = model_s_val.val(
    data=data_path,
    project=project_name,
    name="yolov10s_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10s summary (fused): 106 layers, 7,221,096 parameters, 0 gradients, 21.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 164.9±50.2 MB/s, size: 3.0 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 2.3Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 2.3it/s 1:07
#                    all       4843       4843      0.717      0.772       0.82      0.717
#                  Anger        653        653      0.688      0.741      0.805      0.689
#               Contempt        577        577      0.766      0.787      0.858      0.769
#                Disgust        606        606      0.712      0.696      0.768       0.67
# ...

# %% [markdown]
# ### Testing

# %%
model_s_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10s_train_results/weights/best.pt")

# %%
test_s_result = model_s_test.val(
    data=data_path,
    project=project_name,
    name="yolov10s_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10s summary (fused): 106 layers, 7,221,096 parameters, 0 gradients, 21.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 155.7±44.1 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 846.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 2.1it/s 36.3s
#                    all       2421       2421      0.692      0.758      0.802      0.703
#                  Anger        327        327      0.707       0.79      0.826      0.712
#               Contempt        288        288      0.778      0.765      0.842      0.755
#                Disgust        303        303       0.67      0.643      0.734      0.639
# ...

# %% [markdown]
# ## YOLOv10m (Medium Size)

# %% [markdown]
# ### Train

# %%
model_m = YOLO("yolov10m.pt")

# %%
m_result = model_m.train(
    data=data_path,
    project=project_name,
    name="yolov10m_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Resume

# %%
last_pt = "/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-FER/yolov10m_train_results/weights/last.pt"

# %%
model_m = YOLO(last_pt)

# %%
model_m.train(resume=True)
# Out:
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_m_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10m_train_results/weights/best.pt")

# %%
val_m_result = model_m_val.val(
    data=data_path,
    project=project_name,
    name="yolov10m_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10m summary (fused): 136 layers, 15,317,800 parameters, 0 gradients, 58.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 157.3±52.5 MB/s, size: 2.9 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 1.6Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 2.0it/s 1:16
#                    all       4843       4843      0.718      0.765      0.815      0.711
#                  Anger        653        653      0.703      0.738      0.795      0.679
#               Contempt        577        577      0.763      0.753      0.852       0.76
#                Disgust        606        606      0.673      0.693      0.756      0.657
# ...

# %% [markdown]
# ### Testing

# %%
model_m_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10m_train_results/weights/best.pt")

# %%
test_m_result = model_m_test.val(
    data=data_path,
    project=project_name,
    name="yolov10m_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10m summary (fused): 136 layers, 15,317,800 parameters, 0 gradients, 58.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 114.0±48.3 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 1.6Kit/s 1.6s
# val: New cache created: /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 1.9it/s 39.5s
#                    all       2421       2421      0.713      0.744      0.802      0.703
#                  Anger        327        327      0.757      0.765      0.825       0.71
#               Contempt        288        288      0.774      0.726       0.82      0.739
# ...

# %% [markdown]
# ## YOLOv10l (Large Size)

# %% [markdown]
# ### Train

# %%
model_l = YOLO("yolov10l.pt")

# %%
l_result = model_l.train(
    data=data_path,
    project=project_name,
    name="yolov10l_train_results",
    **train_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# ...

# %% [markdown]
# ### Validation

# %%
model_l_val = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10l_train_results/weights/best.pt")

# %%
val_l_result = model_l_val.val(
    data=data_path,
    project=project_name,
    name="yolov10l_validation_results",
    **val_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10l summary (fused): 174 layers, 24,315,496 parameters, 0 gradients, 120.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 155.2±68.2 MB/s, size: 2.9 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/valid/labels.cache... 4843 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4843/4843 1.6Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 152/152 1.7it/s 1:29
#                    all       4843       4843      0.704      0.765      0.813      0.707
#                  Anger        653        653      0.678      0.752      0.791      0.676
#               Contempt        577        577      0.762      0.747      0.846      0.753
#                Disgust        606        606      0.691       0.66      0.739      0.643
# ...

# %% [markdown]
# ### Testing

# %%
model_l_test = YOLO("/content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed-AffectNet/emotion_detection_yolov10_comparison/yolov10l_train_results/weights/best.pt")

# %%
test_l_result = model_l_test.val(
    data=data_path,
    project=project_name,
    name="yolov10l_testing_results",
    **test_params
)
# Out:
# Ultralytics 8.4.15 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLOv10l summary (fused): 174 layers, 24,315,496 parameters, 0 gradients, 120.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 129.1±49.2 MB/s, size: 2.8 KB)
# val: Scanning /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels... 2421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2421/2421 1.5Kit/s 1.6s
# val: New cache created: /content/dataset/AffectNet-YOLO-Format-Preprocessed/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 76/76 1.7it/s 45.9s
#                    all       2421       2421      0.702      0.745      0.798      0.698
#                  Anger        327        327      0.692      0.795      0.818      0.709
#               Contempt        288        288      0.744      0.701      0.808      0.722
# ...

# %% [markdown]
# ## Save Results

# %%
# !mkdir -p /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed
# !cp -r /content/emotion_detection_yolov10_comparison /content/drive/MyDrive/YOLO-Dataset/YOLO-Results-Fixed
