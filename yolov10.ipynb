# %% [markdown]
# # YOLOv10 Experiments

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_dataset_path = '/content/drive/MyDrive/YOLO-Dataset/processed_emotions_dataset.7z'

# %%
# !cp {zip_dataset_path} /content/

# %%
!7z x /content/processed_emotions_dataset.7z -o/content/dataset/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 346608580 bytes (331 MiB)
#
# Extracting archive: /content/processed_emotions_dataset.7z
# --
# Path = /content/processed_emotions_dataset.7z
# Type = 7z
# Physical Size = 346608580
# Headers Size = 399775
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 10
# Files: 17769
# Size:       352299356
# Compressed: 346608580

# %% [markdown]
# ## Setup

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (8.3.179)
# Requirement already satisfied: numpy>=1.23.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: matplotlib>=3.3.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (3.10.5)
# Requirement already satisfied: opencv-python>=4.6.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (2.8.0+cu129)
# Requirement already satisfied: torchvision>=0.9.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (0.23.0+cu129)
# Requirement already satisfied: tqdm>=4.64.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from ultralytics) (2.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from torch>=1.8.0->ultralytics) (70.2.0)
# Requirement already satisfied: colorama in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\thesis-model\env\yolo-emotions-env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)  # type: ignore
# Out:
# CUDA available: True
# Device name: NVIDIA GeForce RTX 3080
# CUDA version: 12.9

# %%
from ultralytics import YOLO

# %%
# Dataset YAML Path
data_path = "lokasi data.yaml dataset yang digunakan"

# Project Name
project_name = "emotion_detection_yolo_comparison"

# %%
# Training Parameter
train_params = {
    "epochs": 120,
    "patience": 20,
    "batch": 32,
    "imgsz": 640,
    "save": True,
    "save_period": 20,
    "device": 0,
    "pretrained":True,
    "optimizer": "AdamW",
    "seed": 3407,
    "cos_lr": True,
    "close_mosaic": True,
    "freeze": 5,
    "lr0": 0.001,
    "lrf": 0.01,
    "momentum": 0.9,
    "val": True,
    "plots": True,

    # Augmentations
    "hsv_h": 0.015, # Variasi Random Color
    "hsv_s": 0.7,   # Saturation Randomness
    "hsv_v": 0.4,   # Brightness Randomness
    "degrees": 10.0,
    "translate": 0.1,
    "scale": 0.5,
    "fliplr": 0.5,
    "mosaic": 1.0,
}

# %%
# Validation Parameter
val_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'val',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %%
# Testing Parameter
test_params = {
    "imgsz": 640,
    "batch": 32,
    "save_json": True,
    "device": 0,
    "plots": True,
    "split": 'test',
    "verbose": True,
    "save_txt": True,
    "save_conf": True,
}

# %% [markdown]
# ## YOLOv10n (Nano Size)

# %% [markdown]
# ### Train

# %%
model_n = YOLO("yolov10n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.0MB/s]

# %%
n_result = model_n.train(
    data=data_path,
    project=project_name,
    name="yolov10n_train_results",
    **train_params
)

# %% [markdown]
# ### Validation

# %%
model_n_val = YOLO("path/to/best.pt")

# %%
val_n_result = model_n_val.val(
    data=data_path,
    project=project_name,
    name="yolov10n_validation_results",
    **val_params
)

# %% [markdown]
# ### Testing

# %%
model_n_test = YOLO("path/to/best.pt")

# %%
test_n_result = model_n_test.val(
    data=data_path,
    project=project_name,
    name="yolov10n_testing_results",
    **test_params
)

# %% [markdown]
# ## YOLOv10s (Small Size)

# %% [markdown]
# ### Train

# %%
model_s = YOLO("yolov10s.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.0MB/s]

# %%
s_result = model_s.train(
    data=data_path,
    project=project_name,
    name="yolov10s_train_results",
    **train_params
)

# %% [markdown]
# ### Validation

# %%
model_s_val = YOLO("path/to/best.pt")

# %%
val_s_result = model_s_val.val(
    data=data_path,
    project=project_name,
    name="yolov10s_validation_results",
    **val_params
)

# %% [markdown]
# ### Testing

# %%
model_s_test = YOLO("path/to/best.pt")

# %%
test_s_result = model_s_test.val(
    data=data_path,
    project=project_name,
    name="yolov10s_testing_results",
    **test_params
)

# %% [markdown]
# ## YOLOv10m (Medium Size)

# %% [markdown]
# ### Train

# %%
model_m = YOLO("yolov10m.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.0MB/s]

# %%
m_result = model_m.train(
    data=data_path,
    project=project_name,
    name="yolov10m_train_results",
    **train_params
)

# %% [markdown]
# ### Validation

# %%
model_m_val = YOLO("path/to/best.pt")

# %%
val_m_result = model_m_val.val(
    data=data_path,
    project=project_name,
    name="yolov10m_validation_results",
    **val_params
)

# %% [markdown]
# ### Testing

# %%
model_m_test = YOLO("path/to/best.pt")

# %%
test_m_result = model_m_test.val(
    data=data_path,
    project=project_name,
    name="yolov10m_testing_results",
    **test_params
)

# %% [markdown]
# ## Save Results

# %%
# !mkdir -p /content/drive/MyDrive/YOLO-Dataset/YOLO-Results
# !cp -r /content/emotion_detection_yolo_comparison /content/drive/MyDrive/YOLO-Dataset/YOLO-Results
